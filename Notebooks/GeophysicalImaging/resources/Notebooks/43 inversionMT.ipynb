# %%
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
NE0=250 # number of cells in horizontal direction
NE1=250 # number of cells in vertical direction
h0=150. # in horizontal meter [m] grid spacing
h1=150. # in vertical meter [m] grid spacing

# %%
L0, L1=NE0*h0, NE1*h1

# %%
from esys.escript import *
from esys.finley import Rectangle
domain=Rectangle(l0=L0, l1=L1, n0=NE0, n1=NE1)

# %%
H_data=25000

# %%
surface_z=int(H_data/h1)*h1
surface_z+h1/2,L1
# Out:
# (24975.0, 37500.0)

# %% [markdown]
# True conductivity distribution:

# %%
sigma1=2
sigma_bg=0.01

D=300
D=500
H=2000+2000
W=1000
OFFSET=500

# %%
X=ReducedFunction(domain).getX()
m1=whereNonPositive(X[1]-(surface_z-D))
m2=whereNonNegative(X[1]-(surface_z-D-H))
m3=whereNonNegative(X[0]-(L0/2+OFFSET-W/2))
m4=whereNonPositive(X[0]-(L0/2+OFFSET+W/2))
m=m1*m2*m3*m4
sigma_true=(m*sigma1+(1-m)*sigma_bg)*whereNonPositive(X[1]-surface_z)

# %%
sigma_np=convertToNumpy(sigma_true) 
X_np=convertToNumpy(X)

plt.figure()
contour=plt.tricontourf(X_np[0], X_np[1], sigma_np[0], 10)
plt.colorbar(contour)
plt.xlabel('$x_0$ [m]')
plt.ylabel('$x_1$ [m]')
# Out:
# Text(0, 0.5, '$x_1$ [m]')

# %%
m_data=whereNegative(abs(X[1]-(surface_z+h1/2))-h1/2)*whereNegative(abs(X[0]-L0/2)-L0*0.45)

# %%
plt.figure()
contour=plt.tricontourf(X_np[0], X_np[1], convertToNumpy(m_data)[0], 5)
plt.colorbar(contour)
plt.xlabel('$x_0$ [m]')
plt.ylabel('$x_1$ [m]')
# Out:
# Text(0, 0.5, '$x_1$ [m]')

# %% [markdown]
# Get the test data and add some noise:

# %%
from mytools import getMTTE, InversionMTTE, Mu0

# %%
f=10
f=5
data=getMTTE(domain, f, sigma_true)

# %%
data*=(1+0.02*(2*RandomData((), data.getFunctionSpace())-1))

# %% [markdown]
#  set `Wd`:

# %%
Wd=interpolate(m_data, Function(domain))
Wd/=integrate(Wd)
Wd*=1/abs(0.05*abs(data))**2

# %% [markdown]
# Define the cost function:
# reference is only non-zero in the subsurface

# %%
sigma_ref=sigma_bg*whereNonPositive(X[1]-surface_z)

# %%
cf=InversionMTTE(domain, f, data, Wd, z_surface=surface_z, sigma_ref=sigma_ref, mu=1.e-2)

# %%
from esys.downunder import MinimizerLBFGS
solver=MinimizerLBFGS(J=cf, m_tol=1e-3, J_tol=None, imax=500)
solver.setOptions(interpolationOrder=1, truncation=25, restart=60)
m=Scalar(0., Solution(domain))
solver.run(m)
mi=solver.getResult()
# Out:
# inv.minimizer.MinimizerLBFGS: Setting options: {'interpolationOrder': 1, 'truncation': 25, 'restart': 60}
# inv.minimizer.MinimizerLBFGS: initial grad J(x) calculated.
# inv: phi_d, phi_r, sigma= 2.353237e+01, 0.000000e+00, Summary: inf=0 sup=0.01 data points=250000
# inv.minimizer.MinimizerLBFGS: ********** iteration   0 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 23.532371690025773
# inv.minimizer.MinimizerLBFGS: 	H = 1.0
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=20.701 (re-scale = 0.0494631, invH = 1)
# inv.minimizer.linesearch: phi(0)=2.353237e+01
# inv.minimizer.linesearch: phi'(0)=-4.285316e+02
# inv: phi_d, phi_r, sigma= 3.342277e+01, 1.059825e+01, Summary: inf=0 sup=32690.2 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=1.000000e+00, phi(alpha)=4.402102e+01
# inv: phi_d, phi_r, sigma= 1.829773e+01, 2.649563e+00, Summary: inf=0 sup=310.879 data points=250000
# inv.minimizer.linesearch.zoom: iteration 0, alpha=0.5, phi(alpha)=20.9473 (interpolation order = 1)
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch.zoom: 	phi'(alpha)=4.874422e+01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=5.000000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=1.035050e+01, x*m_tol=1.035050e-02
# inv.minimizer.MinimizerLBFGS: ********** iteration   1 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 20.9472964342156
# inv.minimizer.MinimizerLBFGS: 	H = 0.4489349621822376
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=3.19017 (re-scale = 0.0816708, invH = 0.448935)
# inv.minimizer.linesearch: phi(0)=2.094730e+01
# inv.minimizer.linesearch: phi'(0)=-2.515880e+01
# inv: phi_d, phi_r, sigma= 1.939827e+01, 2.890731e+00, Summary: inf=0 sup=511.241 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=5.000000e-01, phi(alpha)=2.228900e+01
# inv: phi_d, phi_r, sigma= 1.457219e+01, 2.712287e+00, Summary: inf=0 sup=398.665 data points=250000
# inv.minimizer.linesearch.zoom: iteration 0, alpha=0.25, phi(alpha)=17.2845 (interpolation order = 1)
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch.zoom: 	phi'(alpha)=-8.466269e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=7.965305e-01, x*m_tol=1.060261e-02
# inv.minimizer.MinimizerLBFGS: ********** iteration   2 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 17.284472573905152
# inv.minimizer.MinimizerLBFGS: 	H = 0.10438567611627597
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.730697 (re-scale = 0.0245439, invH = 0.104386)
# inv.minimizer.linesearch: phi(0)=1.728447e+01
# inv.minimizer.linesearch: phi'(0)=-6.953737e+00
# inv: phi_d, phi_r, sigma= 1.305413e+01, 2.623520e+00, Summary: inf=0 sup=358.511 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=1.567765e+01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-5.863800e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.238062e-01, x*m_tol=1.049722e-02
# inv.minimizer.MinimizerLBFGS: ********** iteration   3 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 15.677654087332206
# inv.minimizer.MinimizerLBFGS: 	H = 0.3847945509307146
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=3.01073 (re-scale = 0.0860322, invH = 0.384795)
# inv.minimizer.linesearch: phi(0)=1.567765e+01
# inv.minimizer.linesearch: phi'(0)=-3.373690e+01
# inv: phi_d, phi_r, sigma= 7.496582e+00, 2.219433e+00, Summary: inf=0 sup=176.337 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=9.716015e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.110972e+01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=1.885830e+00, x*m_tol=9.789947e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration   4 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 9.716014897322427
# inv.minimizer.MinimizerLBFGS: 	H = 0.6286870282676342
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=3.33625 (re-scale = 0.0955296, invH = 0.628687)
# inv.minimizer.linesearch: phi(0)=9.716015e+00
# inv.minimizer.linesearch: phi'(0)=-2.205340e+01
# inv: phi_d, phi_r, sigma= 5.286421e+00, 2.011827e+00, Summary: inf=0 sup=85.3357 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=7.298248e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=2.286724e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=1.457980e+00, x*m_tol=9.064167e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration   5 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 7.29824765333938
# inv.minimizer.MinimizerLBFGS: 	H = 0.34933360076800607
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.72693 (re-scale = 0.0607277, invH = 0.349334)
# inv.minimizer.linesearch: phi(0)=7.298248e+00
# inv.minimizer.linesearch: phi'(0)=-1.169946e+01
# inv: phi_d, phi_r, sigma= 3.816249e+00, 1.889165e+00, Summary: inf=0 sup=50.0749 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=5.705414e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.376990e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=7.928517e-01, x*m_tol=8.531349e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration   6 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 5.7054139652337135
# inv.minimizer.MinimizerLBFGS: 	H = 0.24359041161930797
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.947871 (re-scale = 0.0564228, invH = 0.24359)
# inv.minimizer.linesearch: phi(0)=5.705414e+00
# inv.minimizer.linesearch: phi'(0)=-5.511062e+00
# inv: phi_d, phi_r, sigma= 2.883441e+00, 1.765048e+00, Summary: inf=0 sup=35.1396 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=4.648489e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-2.959083e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=4.284657e-01, x*m_tol=8.175307e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration   7 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 4.648489457959289
# inv.minimizer.MinimizerLBFGS: 	H = 0.2877498267848572
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.728406 (re-scale = 0.056317, invH = 0.28775)
# inv.minimizer.linesearch: phi(0)=4.648489e+00
# inv.minimizer.linesearch: phi'(0)=-3.976809e+00
# inv: phi_d, phi_r, sigma= 2.179848e+00, 1.619429e+00, Summary: inf=0 sup=24.0827 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=3.799276e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-2.784803e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=4.332009e-01, x*m_tol=7.795989e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration   8 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 3.7992764073813454
# inv.minimizer.MinimizerLBFGS: 	H = 0.6297386595542193
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.79084 (re-scale = 0.114435, invH = 0.629739)
# inv.minimizer.linesearch: phi(0)=3.799276e+00
# inv.minimizer.linesearch: phi'(0)=-7.315003e+00
# inv: phi_d, phi_r, sigma= 1.385911e+00, 1.320833e+00, Summary: inf=0 sup=10.1064 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=2.706744e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.131580e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=9.896584e-01, x*m_tol=6.926787e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration   9 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 2.7067435473068215
# inv.minimizer.MinimizerLBFGS: 	H = 0.6335803273531049
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.01365 (re-scale = 0.0969403, invH = 0.63358)
# inv.minimizer.linesearch: phi(0)=2.706744e+00
# inv.minimizer.linesearch: phi'(0)=-2.611458e+00
# inv: phi_d, phi_r, sigma= 1.016637e+00, 1.169449e+00, Summary: inf=0 sup=6.87012 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=2.186086e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.530037e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=4.154425e-01, x*m_tol=6.541416e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  10 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 2.1860856176838386
# inv.minimizer.MinimizerLBFGS: 	H = 0.6383912891386275
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.875276 (re-scale = 0.162286, invH = 0.638391)
# inv.minimizer.linesearch: phi(0)=2.186086e+00
# inv.minimizer.linesearch: phi'(0)=-2.001365e+00
# inv: phi_d, phi_r, sigma= 7.688437e-01, 1.021445e+00, Summary: inf=0 sup=4.61553 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=1.790289e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.144668e+00
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=4.607378e-01, x*m_tol=6.140494e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  11 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 1.7902891682576176
# inv.minimizer.MinimizerLBFGS: 	H = 0.9911518143233476
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.87699 (re-scale = 0.245747, invH = 0.991152)
# inv.minimizer.linesearch: phi(0)=1.790289e+00
# inv.minimizer.linesearch: phi'(0)=-4.249853e+00
# inv: phi_d, phi_r, sigma= 5.261282e-01, 7.818273e-01, Summary: inf=0 sup=1.84605 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=1.307956e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=4.996154e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=1.187495e+00, x*m_tol=5.222559e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  12 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 1.3079555369482834
# inv.minimizer.MinimizerLBFGS: 	H = 1.1876227084573283
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.03501 (re-scale = 0.203199, invH = 1.18762)
# inv.minimizer.linesearch: phi(0)=1.307956e+00
# inv.minimizer.linesearch: phi'(0)=-1.244632e+00
# inv: phi_d, phi_r, sigma= 3.740837e-01, 7.218491e-01, Summary: inf=0 sup=1.50759 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=1.095933e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-4.575479e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.870943e-01, x*m_tol=5.029086e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  13 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 1.0959327901298657
# inv.minimizer.MinimizerLBFGS: 	H = 0.7615047756474913
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.402208 (re-scale = 0.0797734, invH = 0.761505)
# inv.minimizer.linesearch: phi(0)=1.095933e+00
# inv.minimizer.linesearch: phi'(0)=-4.156798e-01
# inv: phi_d, phi_r, sigma= 3.063312e-01, 6.984806e-01, Summary: inf=0 sup=1.53522 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=1.004812e+00
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-3.132379e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=1.742553e-01, x*m_tol=5.062131e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  14 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 1.0048117846295033
# inv.minimizer.MinimizerLBFGS: 	H = 1.185645029075586
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.635717 (re-scale = 0.261313, invH = 1.18565)
# inv.minimizer.linesearch: phi(0)=1.004812e+00
# inv.minimizer.linesearch: phi'(0)=-6.115309e-01
# inv: phi_d, phi_r, sigma= 2.516883e-01, 6.448318e-01, Summary: inf=0 sup=1.56806 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=8.965201e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-2.547788e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.832861e-01, x*m_tol=5.062579e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  15 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.8965200847029788
# inv.minimizer.MinimizerLBFGS: 	H = 1.6471742877538846
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.11363 (re-scale = 0.405792, invH = 1.64717)
# inv.minimizer.linesearch: phi(0)=8.965201e-01
# inv.minimizer.linesearch: phi'(0)=-9.266741e-01
# inv: phi_d, phi_r, sigma= 1.932924e-01, 5.600886e-01, Summary: inf=0 sup=1.79524 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=7.533810e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-2.205798e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=7.394605e-01, x*m_tol=5.259682e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  16 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.753380987601509
# inv.minimizer.MinimizerLBFGS: 	H = 3.0976141053616275
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=1.17286 (re-scale = 0.682662, invH = 3.09761)
# inv.minimizer.linesearch: phi(0)=7.533810e-01
# inv.minimizer.linesearch: phi'(0)=-5.029733e-01
# inv: phi_d, phi_r, sigma= 2.165035e-01, 5.067279e-01, Summary: inf=0 sup=1.74389 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=7.232315e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=2.720299e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=6.294060e-01, x*m_tol=5.291084e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  17 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.7232314577860978
# inv.minimizer.MinimizerLBFGS: 	H = 2.044646316066949
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.57547 (re-scale = 0.555696, invH = 2.04465)
# inv.minimizer.linesearch: phi(0)=7.232315e-01
# inv.minimizer.linesearch: phi'(0)=-2.366762e-01
# inv: phi_d, phi_r, sigma= 2.028909e-01, 4.817966e-01, Summary: inf=0 sup=1.64353 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.846875e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-6.976914e-02
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.481117e-01, x*m_tol=5.263595e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  18 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6846874762109959
# inv.minimizer.MinimizerLBFGS: 	H = 2.9041739082943314
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.756626 (re-scale = 0.622988, invH = 2.90417)
# inv.minimizer.linesearch: phi(0)=6.846875e-01
# inv.minimizer.linesearch: phi'(0)=-2.401337e-01
# inv: phi_d, phi_r, sigma= 1.956753e-01, 4.721315e-01, Summary: inf=0 sup=1.68073 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.678068e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=1.087194e-01
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.649566e-01, x*m_tol=5.285346e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  19 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6678067772501592
# inv.minimizer.MinimizerLBFGS: 	H = 1.5272142064014007
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.248915 (re-scale = 0.256523, invH = 1.52721)
# inv.minimizer.linesearch: phi(0)=6.678068e-01
# inv.minimizer.linesearch: phi'(0)=-6.913256e-02
# inv: phi_d, phi_r, sigma= 1.776253e-01, 4.773426e-01, Summary: inf=0 sup=1.7298 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.549679e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-3.363250e-02
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=4.344220e-02, x*m_tol=5.311565e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  20 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6549678661999723
# inv.minimizer.MinimizerLBFGS: 	H = 0.21264465377076838
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0270442 (re-scale = 0.0420237, invH = 0.212645)
# inv.minimizer.linesearch: phi(0)=6.549679e-01
# inv.minimizer.linesearch: phi'(0)=-1.837742e-02
# inv: phi_d, phi_r, sigma= 1.737631e-01, 4.772205e-01, Summary: inf=0 sup=1.72487 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.509837e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.349536e-02
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=2.564293e-02, x*m_tol=5.307814e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  21 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6509836786187023
# inv.minimizer.MinimizerLBFGS: 	H = 0.5387558751149544
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0452487 (re-scale = 0.167735, invH = 0.538756)
# inv.minimizer.linesearch: phi(0)=6.509837e-01
# inv.minimizer.linesearch: phi'(0)=-1.540642e-02
# inv: phi_d, phi_r, sigma= 1.712669e-01, 4.765075e-01, Summary: inf=0 sup=1.70987 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.477743e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.026904e-02
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=2.337607e-02, x*m_tol=5.297494e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  22 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6477743355917173
# inv.minimizer.MinimizerLBFGS: 	H = 0.42546190128124584
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0357365 (re-scale = 0.134482, invH = 0.425462)
# inv.minimizer.linesearch: phi(0)=6.477743e-01
# inv.minimizer.linesearch: phi'(0)=-1.164324e-02
# inv: phi_d, phi_r, sigma= 1.689599e-01, 4.764188e-01, Summary: inf=0 sup=1.71674 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.453787e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-7.518420e-03
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.323461e-02, x*m_tol=5.299011e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  23 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.645378657020194
# inv.minimizer.MinimizerLBFGS: 	H = 1.0711154160052065
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.045784 (re-scale = 0.37099, invH = 1.07112)
# inv.minimizer.linesearch: phi(0)=6.453787e-01
# inv.minimizer.linesearch: phi'(0)=-6.961737e-03
# inv: phi_d, phi_r, sigma= 1.683785e-01, 4.754973e-01, Summary: inf=0 sup=1.7133 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.438758e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-5.062402e-03
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=2.051801e-02, x*m_tol=5.292997e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  24 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6438758320219418
# inv.minimizer.MinimizerLBFGS: 	H = 0.8866018286168835
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0292014 (re-scale = 0.18839, invH = 0.886602)
# inv.minimizer.linesearch: phi(0)=6.438758e-01
# inv.minimizer.linesearch: phi'(0)=-4.834026e-03
# inv: phi_d, phi_r, sigma= 1.676451e-01, 4.751873e-01, Summary: inf=0 sup=1.71982 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.428324e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-3.513030e-03
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=2.213841e-02, x*m_tol=5.292782e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  25 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6428324303237908
# inv.minimizer.MinimizerLBFGS: 	H = 1.4840596302199047
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.059438 (re-scale = 0.371589, invH = 1.48406)
# inv.minimizer.linesearch: phi(0)=6.428324e-01
# inv.minimizer.linesearch: phi'(0)=-5.002938e-03
# inv: phi_d, phi_r, sigma= 1.674356e-01, 4.745786e-01, Summary: inf=0 sup=1.7275 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.420142e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.542660e-03
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.056804e-02, x*m_tol=5.290636e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  26 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6420141880968392
# inv.minimizer.MinimizerLBFGS: 	H = 1.0801498995261043
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0395793 (re-scale = 0.230554, invH = 1.08015)
# inv.minimizer.linesearch: phi(0)=6.420142e-01
# inv.minimizer.linesearch: phi'(0)=-2.844569e-03
# inv: phi_d, phi_r, sigma= 1.675096e-01, 4.739293e-01, Summary: inf=0 sup=1.72984 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.414389e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-1.758746e-03
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=2.178539e-02, x*m_tol=5.286716e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  27 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6414388625125943
# inv.minimizer.MinimizerLBFGS: 	H = 1.748363701154684
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0321178 (re-scale = 0.266682, invH = 1.74836)
# inv.minimizer.linesearch: phi(0)=6.414389e-01
# inv.minimizer.linesearch: phi'(0)=-1.412747e-03
# inv: phi_d, phi_r, sigma= 1.669244e-01, 4.742299e-01, Summary: inf=0 sup=1.7415 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.411543e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-8.635956e-04
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=2.319387e-02, x*m_tol=5.289149e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  28 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6411542944788002
# inv.minimizer.MinimizerLBFGS: 	H = 3.9184535940869587
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0764821 (re-scale = 0.723931, invH = 3.91845)
# inv.minimizer.linesearch: phi(0)=6.411543e-01
# inv.minimizer.linesearch: phi'(0)=-2.031311e-03
# inv: phi_d, phi_r, sigma= 1.662039e-01, 4.747194e-01, Summary: inf=0 sup=1.76291 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.409233e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=1.835359e-04
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=2.500000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=4.618915e-02, x*m_tol=5.292259e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  29 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6409233326446615
# inv.minimizer.MinimizerLBFGS: 	H = 3.852974928401306
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0952732 (re-scale = 0.481743, invH = 3.85297)
# inv.minimizer.linesearch: phi(0)=6.409233e-01
# inv.minimizer.linesearch: phi'(0)=-2.641890e-03
# inv: phi_d, phi_r, sigma= 1.674594e-01, 4.737974e-01, Summary: inf=0 sup=1.78368 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=2.500000e-01, phi(alpha)=6.412568e-01
# inv: phi_d, phi_r, sigma= 1.666671e-01, 4.741745e-01, Summary: inf=0 sup=1.77326 data points=250000
# inv.minimizer.linesearch.zoom: iteration 0, alpha=0.125, phi(alpha)=0.640842 (interpolation order = 1)
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch.zoom: 	phi'(alpha)=1.334160e-03
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=1.250000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=3.315434e-02, x*m_tol=5.290947e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  30 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6408416311350782
# inv.minimizer.MinimizerLBFGS: 	H = 2.211662812220025
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0336753 (re-scale = 0.28175, invH = 2.21166)
# inv.minimizer.linesearch: phi(0)=6.408416e-01
# inv.minimizer.linesearch: phi'(0)=-7.995831e-04
# inv: phi_d, phi_r, sigma= 1.669183e-01, 4.738452e-01, Summary: inf=0 sup=1.77417 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=1.250000e-01, phi(alpha)=6.407635e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-4.510210e-04
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=1.250000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=7.925822e-03, x*m_tol=5.289531e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  31 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6407634693264043
# inv.minimizer.MinimizerLBFGS: 	H = 1.441778236187117
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0370372 (re-scale = 0.190294, invH = 1.44178)
# inv.minimizer.linesearch: phi(0)=6.407635e-01
# inv.minimizer.linesearch: phi'(0)=-1.180727e-03
# inv: phi_d, phi_r, sigma= 1.674958e-01, 4.732092e-01, Summary: inf=0 sup=1.77201 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=1.250000e-01, phi(alpha)=6.407050e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=2.452567e-04
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=1.250000e-01
# inv.minimizer.MinimizerLBFGS: Solution checked: dx=1.090163e-02, x*m_tol=5.285965e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  32 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6407049677913079
# inv.minimizer.MinimizerLBFGS: 	H = 0.6667427232833126
# inv.minimizer.MinimizerLBFGS: rescale of search direction : r=0.0153742 (re-scale = 0.098123, invH = 0.666743)
# inv.minimizer.linesearch: phi(0)=6.407050e-01
# inv.minimizer.linesearch: phi'(0)=-5.308222e-04
# inv: phi_d, phi_r, sigma= 1.675409e-01, 4.731090e-01, Summary: inf=0 sup=1.77268 data points=250000
# inv.minimizer.linesearch: iteration 1, alpha=1.250000e-01, phi(alpha)=6.406499e-01
# inv.minimizer.linesearch: grad J(x+alpha*p) calculated.
# inv.minimizer.linesearch: phi'(alpha)=-3.505217e-04
# inv.minimizer.MinimizerLBFGS: Search direction scaling alpha=1.250000e-01
# inv.minimizer.MinimizerLBFGS: Solution has converged: dx=4.220568e-03, x*m_tol=5.285354e-03
# inv.minimizer.MinimizerLBFGS: ********** iteration  33 **********
# inv.minimizer.MinimizerLBFGS: 	J(x) = 0.6406498820766853
# inv.minimizer.MinimizerLBFGS: Success after 32 iterations!

# %%
# %matplotlib notebook
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
sigma=cf.sigma_ref*exp(mi)
sigma_np=convertToNumpy(sigma)
x_np=convertToNumpy(sigma.getX())
plt.figure()
contour=plt.tricontourf(x_np[0], x_np[1], sigma_np[0], 20)
plt.colorbar(contour)
plt.xlabel('$x_0$ [m]')
plt.ylabel('$x_1$ [m]')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, '$x_1$ [m]')

# %%
from esys.escript.pdetools import Locator
x0_transect=np.linspace(h0/2, L0-h0/2, NE0)
x_transect=[ (x0, surface_z+h1/2) for x0 in np.linspace(L0/2-L0*0.45, L0/2+L0*0.45, int(NE0*0.9)) ]
transect_locator=Locator(where=ReducedFunction(domain), x=x_transect )
x0_transect=[ x[0] for x in transect_locator.getX() ]

# %%
data_transect=transect_locator.getValue(1./(cf.omega*Mu0)*abs(data)**2)

# %%
datai=getMTTE(domain, f, sigma)
datai_transect=transect_locator.getValue(1./(cf.omega*Mu0)*abs(datai)**2)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x0_transect, data_transect, label="input", s=1)
plt.plot(x0_transect, datai_transect, label="recovered")
plt.xlabel('offset [m]')
plt.ylabel('rho_a')
plt.legend()
plt.title("apparent resistivity over transect @ height %g m"%(transect_locator.getX()[0][1]))
# Out:
# <div id='9428f3bf-6394-4762-8c07-525fff18cb0c'></div>
# Text(0.5, 1.0, 'apparent resistivity over transect @ height 24975 m')
